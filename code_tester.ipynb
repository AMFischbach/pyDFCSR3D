# %%
from csr3d import CSR3D

# %%
# %matplotlib widget
# %load_ext line_profiler
csr_3d = CSR3D(input_file= 'input/dipole_config.yaml')

#%lprun -f CSR3D.get_csr_integrands csr_3d.run()
csr_3d.run()
csr_3d.save_data("/Users/treyfischbach/Desktop/Stuff/Research/SLAC 2024/SULI 2024/3D Wake Benchmarking/new 3D code output", "s0 wakes not applied 3D")
# Out:
# CSR3D Object Succesfully Initialized
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
